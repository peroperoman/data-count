# %%
import pandas as pd
import numpy as np
import datetime
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('sampla-data', names=('date', 'total'), header=None)

# %%
df.head()
# Out:
#          date  total
# 0  2016-01-01     66
# 1  2016-01-02     46
# 2  2016-01-03     46
# 3  2016-01-04     82
# 4  2016-01-05     51

# %%
df.tail()
# Out:
#             date    total
# 1444  2019-12-15   406546
# 1445  2019-12-16  1663937
# 1446  2019-12-17  1588670
# 1447  2019-12-18  1479213
# 1448  2019-12-19  1476708

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
df = df.set_index("date")

# %%
df.plot(figsize=(18,4))

# %%
df['total'].mean()
# Out:
# 518528.4679089027

# %%
df['date']
# Out:
# 0      2016-01-01
# 1      2016-01-02
# 2      2016-01-03
# 3      2016-01-04
# 4      2016-01-05
#           ...
# 1444   2019-12-15
# 1445   2019-12-16
# 1446   2019-12-17
# 1447   2019-12-18
# 1448   2019-12-19
# Name: date, Length: 1449, dtype: datetime64[ns]

# %%
df[df['date'] > datetime.datetime(2019, 1, 1)]
# Out:
#            date    total
# 1097 2019-01-02   173044
# 1098 2019-01-03   252630
# 1099 2019-01-04   656716
# 1100 2019-01-05   318149
# 1101 2019-01-06   210110
# ...         ...      ...
# 1444 2019-12-15   406546
# 1445 2019-12-16  1663937
# 1446 2019-12-17  1588670
# 1447 2019-12-18  1479213
# 1448 2019-12-19  1476708
#
# [352 rows x 2 columns]

# %%
df_2016 = df[(df['date'] >= datetime.datetime(2016, 1, 1)) & (df['date'] <= datetime.datetime(2016, 12, 31))]
df_2017 = df[(df['date'] >= datetime.datetime(2017, 1, 1)) & (df['date'] <= datetime.datetime(2017, 12, 31))]
df_2018 = df[(df['date'] >= datetime.datetime(2018, 1, 1)) & (df['date'] <= datetime.datetime(2018, 12, 31))]
df_2019 = df[(df['date'] >= datetime.datetime(2019, 1, 1)) & (df['date'] <= datetime.datetime(2019, 12, 31))]

# %%
df_2019['total'].mean()
# Out:
# 1009628.5410764873

# %%
df_2019['total'].max()
# Out:
# 4701693

# %%
df_2019['total'].min()
# Out:
# 173044

# %%
df_2018['total'].mean()
# Out:
# 592662.8

# %%
df_2018['total'].max()
# Out:
# 2279759

# %%
df_2018['total'].min()
# Out:
# 96914

# %%
df_2019['total'].describe()
# Out:
# count    3.530000e+02
# mean     1.009629e+06
# std      5.442058e+05
# min      1.730440e+05
# 25%      4.697280e+05
# 50%      1.081593e+06
# 75%      1.392799e+06
# max      4.701693e+06
# Name: total, dtype: float64

# %%
df_2018
# Out:
#            date   total
# 731  2018-01-01  119610
# 732  2018-01-02   96914
# 733  2018-01-03  116937
# 734  2018-01-04  371792
# 735  2018-01-05  522540
# ...         ...     ...
# 1091 2018-12-27  896017
# 1092 2018-12-28  844420
# 1093 2018-12-29  247301
# 1094 2018-12-30  198175
# 1095 2018-12-31  184231
#
# [365 rows x 2 columns]
