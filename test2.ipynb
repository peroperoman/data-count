# %%
import pandas as pd
import numpy as np
import datetime
from matplotlib import pyplot as plt

# %matplotlib inline
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('sample-data', names=('date', 'total'), header=None)

# %%
df.head()
# Out:
#          date  total
# 0  2016-01-01     66
# 1  2016-01-02     46
# 2  2016-01-03     46
# 3  2016-01-04     82
# 4  2016-01-05     51

# %%
df.tail()
# Out:
#             date    total
# 1444  2019-12-15   406546
# 1445  2019-12-16  1663937
# 1446  2019-12-17  1588670
# 1447  2019-12-18  1479213
# 1448  2019-12-19  1476708

# %%
df.dtypes
# Out:
# date     object
# total     int64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
df = df.set_index("date")

# %%
df.head()
# Out:
#             total
# date
# 2016-01-01     66
# 2016-01-02     46
# 2016-01-03     46
# 2016-01-04     82
# 2016-01-05     51

# %%
df.plot(figsize=(18,4))

# %%
df.resample('Y').max()
# Out:
#               total
# date
# 2016-12-31   755746
# 2017-12-31   999426
# 2018-12-31  2279759
# 2019-12-31  4701693

# %%
df['2019'].describe()
# Out:
#            total
# count     353.00
# mean  1009628.54
# std    544205.75
# min    173044.00
# 25%    469728.00
# 50%   1081593.00
# 75%   1392799.00
# max   4701693.00

# %%
df['2018'].describe()
# Out:
#            total
# count     365.00
# mean   592662.80
# std    315505.18
# min     96914.00
# 25%    247301.00
# 50%    676678.00
# 75%    792258.00
# max   2279759.00

# %%
df.resample('M').mean().plot(figsize=(18,4))

# %%
df2 = df.assign(mean_manth=df.resample('M').mean())

# %%
df3 = df2.fillna(0)

# %%
df3.plot(figsize=(18,4))

# %%
df4 = df3.assign(rate_change=df['total'].diff(7))

# %%
df4.plot(figsize=(18,4))

# %%
df['total'].pct_change().plot(figsize=(18,4))

# %%
df_2018['total'].min()
# Out:
# 96914

# %%
df_2019['total'].describe()
# Out:
# count    3.530000e+02
# mean     1.009629e+06
# std      5.442058e+05
# min      1.730440e+05
# 25%      4.697280e+05
# 50%      1.081593e+06
# 75%      1.392799e+06
# max      4.701693e+06
# Name: total, dtype: float64

# %%
df_2018
# Out:
#            date   total
# 731  2018-01-01  119610
# 732  2018-01-02   96914
# 733  2018-01-03  116937
# 734  2018-01-04  371792
# 735  2018-01-05  522540
# ...         ...     ...
# 1091 2018-12-27  896017
# 1092 2018-12-28  844420
# 1093 2018-12-29  247301
# 1094 2018-12-30  198175
# 1095 2018-12-31  184231
#
# [365 rows x 2 columns]

# %%
df[].plot(figsize=(18,4))
# Out:
#   File "<ipython-input-93-2e34d18d5d84>", line 1
#     df[].plot(figsize=(18,4))
#        ^
# SyntaxError: invalid syntax
